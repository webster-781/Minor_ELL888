# %%
import numpy as np
from getData import *
from matplotlib import pyplot as plt
import pandas as pd
from Algorithms import *

# X, y = getRandom([1,2],100)
# X_img = X.reshape(X.shape[0],28,28)

# %%
# Using it for sample data(with no missing values)
X,y = getRandom(amount = 200, classes = [0,1])
print(X.shape,y.shape)

D = getD(X)
A = A = KnnE(D, k = 2)
plot_values(D = D, y = y, title = "For Sample EEG data(no missing values)", K = np.linspace(1,20,num=10))
# Out:
# (400, 784) (400,)

# %%
X_transformed = Transform(X)
scatterPlot(X_transformed,y)
# Out:
# <class 'int'>
# <class 'int'>

# %%
visualise(X_transformed,y,A)
# Out:
# 99.49409780775717 %

# %%
md = getMissData(X)
D1 = getSpecialDistance(md)

# %%
plot_values(D = D1, y = y, title = "For missing attributes, special Distance function", K = np.linspace(1,20,num=10))

# %%
visualise(X_transformed,y,KnnE(D1,k=2))
# Out:
# 49.87468671679198 %

# %%
X2 = imputeMean(md)
D2 = getD(X2)
plot_values(D = D2, y = y, title = "For missing attributes, using mean imputer", K = np.linspace(1,20,num=10))

# %%
visualise(X_transformed,y,KnnE(D2,k=2))
# Out:
# 99.49238578680203 %

# %%
X3 = imputeKNN(md,k = 5)
D3 = getD(X3)
plot_values(D = D3, y = y, title = "For missing attributes, using KNN imputer(k=5)", K = np.linspace(1,20,num=10))

# %%
visualise(X_transformed,y,KnnE(D3,k=2))
# Out:
# 99.49409780775717 %

# %%
n = 10
k = 1
x = np.random.random_sample((n))
y = np.random.random_sample((n))
attr = np.array([np.sin((x[i]*x[i] + y[i]*y[i])/2) for i in range(n)])
print(df)
df = pd.DataFrame({
    'x' : x,
    'y' : y,
    'attr' : attr 
})
plt.scatter(df.x, df.y, s=200, c=df.attr, cmap='viridis')

# %%
for i in range(n):
    for j in range(k):
        ind = A[i].indices[j]
        x_val = [x[i],x[ind]]
        y_val = [y[i],y[ind]]
        plt.plot(x_val,y_val,color = 'black')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f46642203365> in <module>
# ----> 1 for i in range(n):
#       2     for j in range(k):
#       3         ind = A[i].indices[j]
#       4         x_val = [x[i],x[ind]]
#       5         y_val = [y[i],y[ind]]
#
# NameError: name 'n' is not defined

# %%
q = np.array([[0,0],[1,0]])
r = q.T
p = q + r
p[p.nonzero()] = 1
print(p)
# Out:
# [[0 1]
#  [1 0]]

# %%
rng = np.random.default_rng()
numbers = rng.choice(20, size=10, replace=False)
print(numbers)
# Out:
# [18 10 16  1  2 14  6  9  0 19]
