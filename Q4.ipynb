# %%
from Algorithms import *
from getData import *
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-95320febc6eb> in <module>
#       1 from Algorithms import *
# ----> 2 from getData import *
#
# ~/Downloads/Courses/ELL888/Minor/Minor_ELL888/getData.py in <module>
#       1 import numpy as np
#       2 from keras.datasets import mnist
# ----> 3 import pandas as pd
#       4 from sklearn.preprocessing import LabelEncoder
#       5 from sklearn.preprocessing import OneHotEncoder
#
# /usr/local/lib/python3.9/site-packages/pandas/__init__.py in <module>
#      20
#      21 # numpy compat
# ---> 22 from pandas.compat import (
#      23     np_version_under1p18 as _np_version_under1p18,
#      24     is_numpy_dev as _is_numpy_dev,
#
# /usr/local/lib/python3.9/site-packages/pandas/compat/__init__.py in <module>
#      13
#      14 from pandas._typing import F
# ---> 15 from pandas.compat.numpy import (
#      16     is_numpy_dev,
#      17     np_array_datetime64_compat,
#
# /usr/local/lib/python3.9/site-packages/pandas/compat/numpy/__init__.py in <module>
#       5 import numpy as np
#       6
# ----> 7 from pandas.util.version import Version
#       8
#       9 # numpy versioning
#
# /usr/local/lib/python3.9/site-packages/pandas/util/__init__.py in <module>
# ----> 1 from pandas.util._decorators import (  # noqa
#       2     Appender,
#       3     Substitution,
#       4     cache_readonly,
#       5 )
#
# /usr/local/lib/python3.9/site-packages/pandas/util/_decorators.py in <module>
#      12 import warnings
#      13
# ---> 14 from pandas._libs.properties import cache_readonly  # noqa
#      15 from pandas._typing import F
#      16
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/__init__.py in <module>
#      11
#      12
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/interval.pyx in init pandas._libs.interval()
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/hashtable.pyx in init pandas._libs.hashtable()
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/missing.pyx in init pandas._libs.missing()
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/tslibs/__init__.py in <module>
#      47     to_offset,
#      48 )
# ---> 49 from pandas._libs.tslibs.period import (
#      50     IncompatibleFrequency,
#      51     Period,
#
# /usr/local/Cellar/python@3.9/3.9.10/Frameworks/Python.framework/Versions/3.9/lib/python3.9/importlib/_bootstrap.py in parent(self)
#
# KeyboardInterrupt:

# %%
R,I,C,y = getAdultData(amount = 1000)
print(R.shape,I.shape,C.shape,y.shape)
# Out:
# (2000, 3) (2000, 3) (2000, 90) (2000,)

# %%
D = getAllDist(R,I,C)
plot_values(D = D, y = y, title = "For Sample Data (using combined distance function)", K = list(range(1,11)))

# %%
D1 = getRealDist(R)
plot_values(D = D1, y = y, title = "For Sample Data (using only real attribute distance function)", K = np.linspace(1,40,num=10))

# %%
D2 = getRealDist(I)
plot_values(D = D2, y = y, title = "For Sample Data (using only integer attribute distance function)", K = np.linspace(1,40,num=10))

# %%
D3 = getCatDist(C)
plot_values(D = D3, y = y, title = "For Sample Data (using only categorical attribute distance function)", K = np.linspace(1,40,num=10))

# %%
X = np.concatenate((R,I,C),axis = 1)

# %%
print(X.shape)
# Out:
# (2000, 96)

# %%
X_transformed = Transform(X)

# %%
scatterPlot(X_transformed,y)
# Out:
# <class 'int'>
# <class 'int'>

# %%
A = KnnE(D,k=2)
visualise(X_transformed,y,A)
# Out:
# 72.81488866733133 %

# %%
RM,IM,CM,yM = getAdultData2(amount = 1000, col = 'Sex', set= ' Male')
RF,IF,CF,yF = getAdultData2(amount = 1000, col = 'Sex', set= ' Female')
DM = getAllDist(RM,IM,CM)
DF = getAllDist(RF,IF,CF)
effM = np.array(all_effs(DM,yM))
effF = np.array(all_effs(DF,yF))
print(effM.shape)
eff = (effM + effF)/2
# Out:
# (2, 10)

# %%
K = list(range(1,11))
plt.plot(K,eff[0],color = 'green')
plt.plot(K,eff[1], color = 'blue')

plt.xlabel("Number of Neighbours(k)")
plt.ylabel("Efficiency of Graph")
plt.title("Constructing different graphs for different Genders(Male and Female), then assembling")
plt.legend(['Neighbourhood Efficiency','Classification Efficiency'])
plt.show()

# %%
RM,IM,CM,yM = getAdultData2(amount = 1000, col = 'Marital-status', set= ' Married-civ-spouse')
RF,IF,CF,yF = getAdultData2(amount = 1000, col = 'Marital-status', set= ' Never-married')
DM = getAllDist(RM,IM,CM)
DF = getAllDist(RF,IF,CF)
effM = np.array(all_effs(DM,yM))
effF = np.array(all_effs(DF,yF))
print(effM.shape)
eff = (effM + effF)/2
# Out:
# (2, 10)

# %%
K = list(range(1,11))
plt.plot(K,eff[0],color = 'green')
plt.plot(K,eff[1], color = 'blue')

plt.xlabel("Number of Neighbours(k)")
plt.ylabel("Efficiency of Graph")
plt.title("Constructing different graphs for different Marital-status, then assembling")
plt.legend(['Homeophilic Efficiency','Classification Efficiency'])
plt.show()
